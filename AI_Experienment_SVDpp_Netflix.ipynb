# %%
from SVDModel import SVDModel
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import time
from joblib import Parallel, delayed
import pickle
import os.path
from pathlib import Path

np.random.seed(3362)

# %%
# Parameters
PARAM = dict()
PARAM['path'] = {
  'ml':'./data/MovieLens25M/',
  'netflix':'./data/NetflixPrize/'
}

PARAM
# Out:
# {'path': {'ml': './data/MovieLens25M/', 'netflix': './data/NetflixPrize/'}}

# %%
names = ['userId','rating','timestamp','movieId']
df_netflix = pd.read_csv(PARAM['path']['netflix']+'data_1.txt', names=names, low_memory=False)
df_netflix_2 = pd.read_csv(PARAM['path']['netflix']+'data_2.txt', names=names, low_memory=False)
df_netflix_3 = pd.read_csv(PARAM['path']['netflix']+'data_3.txt', names=names, low_memory=False)
df_netflix_4 = pd.read_csv(PARAM['path']['netflix']+'data_4.txt', names=names, low_memory=False)
df_netflix = pd.concat([df_netflix,df_netflix_2,df_netflix_3,df_netflix_4], names=names)
df_netflix['movieId'] = df_netflix['movieId'].fillna(method='ffill')
df_netflix = df_netflix.dropna()
df_netflix['rating'] = df_netflix['rating'].astype(np.int8)
df_netflix['movieId'] = df_netflix['movieId'].astype(np.int16)
df_netflix['userId'] = df_netflix['userId'].astype(np.int32)
df_netflix['timestamp'] = pd.to_datetime(df_netflix['timestamp']).view(dtype=np.int64) // 10 ** 9
df_movies = pd.read_csv(PARAM['path']['netflix']+'movie_titles.csv',
                        encoding='latin-1',
                        names=['movieId','release_year','title'],
                        usecols=range(3))
NETFLIX = {
  'ratings': df_netflix[['userId','movieId','rating','timestamp']].sample(2**16),
  'movies': df_movies,
  'm_movies': df_netflix['movieId'].nunique(),
  'n_users': df_netflix['userId'].nunique(),
  'n_ratings': len(df_netflix)
}

# %%
print(NETFLIX['ratings'].shape)
print(NETFLIX['movies'].shape)
# Out:
# (65536, 4)
# (17770, 3)

# %%
PARAM['features'] = [3,30,150,300]
PARAM['lr'] = [1e-2,1e-3,1e-4]
PARAM['epochs'] = [11,101,201,301,501]
PARAM['weight_decay'] = [0.02,0.2,2]
PARAM['stopping'] = 0.001
 
data = 'NETFLIX'
 
if data=='ML_25M':
    resultDir = 'model_movielens'
else:
    resultDir = 'model_netflix'

print('Creating SVD++ Model')
svd = SVDModel()
print("Created\nLoading Data")
if data=='ML_25M':
    svd.data_loader(data=ML_25M['ratings'],
                    n_items = ML_25M['m_movies'],
                    n_users= ML_25M['n_users'])
else:
    svd.data_loader(data=NETFLIX['ratings'],
                    n_items = NETFLIX['m_movies'],
                    n_users= NETFLIX['n_users'])
print("Loaded Data\nSpliting Data")
svd.split(0.8,0.8)
print("Splitted Data\nTraining...")

def train_model(features, lr, epochs, data, weight_decay):
   
 
    if os.path.isfile(f'./{resultDir}/svdpp/result/{features}_{lr}_{epochs}_{weight_decay}_0.001.pkl'):
        return
    print(f"==============================")
    print(f'features: {features}\nlearning rate: {lr}\nEpochs: {epochs}\nweight decay: {weight_decay}\nstopping: 0.001\n')
    svd.mode = 'svd++'
    svd.features = features
    svd.lr = lr
    svd.epochs = epochs
    svd.weight_decay = weight_decay
    svd.stopping = 0.001
 
    start = time.perf_counter()
    result = svd.training()
    print('Time used =', time.perf_counter()-start)
   
    print('Saving Model')
#     svd.data = []
    Path(f"./{resultDir}").mkdir(parents=True, exist_ok=True)
    Path(f"./{resultDir}/svdpp").mkdir(parents=True, exist_ok=True)
    Path(f"./{resultDir}/svdpp/model").mkdir(parents=True, exist_ok=True)
    Path(f"./{resultDir}/svdpp/result").mkdir(parents=True, exist_ok=True)
   
   
    # with open(f'./{resultDir}/svdpp/model/{features}_{lr}_{epochs}_{weight_decay}_-1.pkl', 'wb') as out:
    #     pickle.dump(svd, out, pickle.HIGHEST_PROTOCOL)
    #     out.close()
    with open(f'./{resultDir}/svdpp/result/{features}_{lr}_{epochs}_{weight_decay}_0.001.pkl', 'wb') as out:
        pickle.dump(result, out, pickle.HIGHEST_PROTOCOL)
        out.close()
    print(f"==============================")
    return svd, result
# Out:
# Creating SVD++ Model
# Created
# Loading Data
# Loaded Data
# Spliting Data
# Splitted Data
# Training...

# %%
for epochs in PARAM['epochs']:
    for features in PARAM['features']:
        for lr in PARAM['lr']:            
            for weight_decay in PARAM['weight_decay']:
                for data in ['NETFLIX']:
                    train_model(features, lr, epochs, data, weight_decay)
# Out:
# ==============================
# features: 3
# learning rate: 0.01
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.064  | Valid : 1.105  | Time : 1.10499s
# Epoch :   11  | Train : 0.797  | Valid : 1.063  | Time : 8.52542s
# Training stopped:
# Epoch :   11  | Train Loss : 0.797  | Valid Loss: 1.063  | Test Loss: 1.076
# Time used = 10.035988458000247
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.01
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.067  | Valid : 1.108  | Time : 0.88552s
# Epoch :   11  | Train : 0.807  | Valid : 1.064  | Time : 8.37541s
# Training stopped:
# Epoch :   11  | Train Loss : 0.807  | Valid Loss: 1.064  | Test Loss: 1.079
# Time used = 9.671038999999837
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.01
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.095  | Valid : 1.133  | Time : 0.86341s
# Training stopped:
# Epoch :    9  | Train Loss : 0.914  | Valid Loss: 1.109  | Test Loss: 1.127
# Time used = 8.003226333999919
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.001
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.157  | Valid : 1.165  | Time : 0.89619s
# Epoch :   11  | Train : 1.059  | Valid : 1.102  | Time : 8.31390s
# Training stopped:
# Epoch :   11  | Train Loss : 1.059  | Valid Loss: 1.102  | Test Loss: 1.116
# Time used = 9.608036415999777
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.001
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.157  | Valid : 1.166  | Time : 0.87674s
# Epoch :   11  | Train : 1.062  | Valid : 1.105  | Time : 8.34372s
# Training stopped:
# Epoch :   11  | Train Loss : 1.062  | Valid Loss: 1.105  | Test Loss: 1.119
# Time used = 9.62215037499982
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.001
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.160  | Valid : 1.169  | Time : 0.91658s
# Epoch :   11  | Train : 1.092  | Valid : 1.132  | Time : 8.29935s
# Training stopped:
# Epoch :   11  | Train Loss : 1.092  | Valid Loss: 1.132  | Test Loss: 1.149
# Time used = 9.636144208000132
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.0001
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.180  | Valid : 1.185  | Time : 0.83994s
# Epoch :   11  | Train : 1.155  | Valid : 1.164  | Time : 8.43471s
# Training stopped:
# Epoch :   11  | Train Loss : 1.155  | Valid Loss: 1.164  | Test Loss: 1.182
# Time used = 9.67145712499996
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.0001
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.180  | Valid : 1.185  | Time : 0.88511s
# Epoch :   11  | Train : 1.155  | Valid : 1.164  | Time : 8.28771s
# Training stopped:
# Epoch :   11  | Train Loss : 1.155  | Valid Loss: 1.164  | Test Loss: 1.183
# Time used = 9.571732792000148
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.0001
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.180  | Valid : 1.185  | Time : 0.88981s
# Epoch :   11  | Train : 1.158  | Valid : 1.167  | Time : 8.23744s
# Training stopped:
# Epoch :   11  | Train Loss : 1.158  | Valid Loss: 1.167  | Test Loss: 1.186
# Time used = 9.523415999999997
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.01
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.067  | Valid : 1.112  | Time : 0.90839s
# Epoch :   11  | Train : 0.768  | Valid : 1.066  | Time : 8.37160s
# Training stopped:
# Epoch :   11  | Train Loss : 0.768  | Valid Loss: 1.066  | Test Loss: 1.078
# Time used = 9.71410775000004
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.01
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.070  | Valid : 1.114  | Time : 0.88444s
# Epoch :   11  | Train : 0.798  | Valid : 1.067  | Time : 8.36327s
# Training stopped:
# Epoch :   11  | Train Loss : 0.798  | Valid Loss: 1.067  | Test Loss: 1.080
# Time used = 9.670197333000033
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.01
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.097  | Valid : 1.137  | Time : 0.91979s
# Training stopped:
# Epoch :    9  | Train Loss : 0.911  | Valid Loss: 1.109  | Test Loss: 1.127
# Time used = 8.161586290999821
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.001
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.163  | Valid : 1.171  | Time : 0.90552s
# Epoch :   11  | Train : 1.061  | Valid : 1.109  | Time : 8.53202s
# Training stopped:
# Epoch :   11  | Train Loss : 1.061  | Valid Loss: 1.109  | Test Loss: 1.121
# Time used = 9.860734459000014
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.001
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.163  | Valid : 1.172  | Time : 0.88324s
# Epoch :   11  | Train : 1.064  | Valid : 1.110  | Time : 8.40943s
# Training stopped:
# Epoch :   11  | Train Loss : 1.064  | Valid Loss: 1.110  | Test Loss: 1.123
# Time used = 9.738265707999744
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.001
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.166  | Valid : 1.175  | Time : 0.92221s
# Epoch :   11  | Train : 1.093  | Valid : 1.136  | Time : 8.35638s
# Training stopped:
# Epoch :   11  | Train Loss : 1.093  | Valid Loss: 1.136  | Test Loss: 1.152
# Time used = 9.711913832999926
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.0001
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.186  | Valid : 1.190  | Time : 0.88917s
# Epoch :   11  | Train : 1.161  | Valid : 1.169  | Time : 8.80836s
# Training stopped:
# Epoch :   11  | Train Loss : 1.161  | Valid Loss: 1.169  | Test Loss: 1.187
# Time used = 10.148772291000114
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.0001
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.186  | Valid : 1.190  | Time : 0.91397s
# Epoch :   11  | Train : 1.161  | Valid : 1.170  | Time : 8.48834s
# Training stopped:
# Epoch :   11  | Train Loss : 1.161  | Valid Loss: 1.170  | Test Loss: 1.187
# Time used = 9.829978417000348
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.0001
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.187  | Valid : 1.192  | Time : 0.87083s
# Epoch :   11  | Train : 1.165  | Valid : 1.175  | Time : 8.35789s
# Training stopped:
# Epoch :   11  | Train Loss : 1.165  | Valid Loss: 1.175  | Test Loss: 1.191
# Time used = 9.645354500000394
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.01
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.110  | Valid : 1.172  | Time : 0.96672s
# Epoch :   11  | Train : 0.689  | Valid : 1.085  | Time : 8.77593s
# Training stopped:
# Epoch :   11  | Train Loss : 0.689  | Valid Loss: 1.085  | Test Loss: 1.093
# Time used = 10.293844166999861
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.01
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.109  | Valid : 1.170  | Time : 0.91179s
# Epoch :   11  | Train : 0.772  | Valid : 1.084  | Time : 8.68082s
# Training stopped:
# Epoch :   11  | Train Loss : 0.772  | Valid Loss: 1.084  | Test Loss: 1.094
# Time used = 10.149872166000023
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.01
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.121  | Valid : 1.175  | Time : 0.99786s
# Epoch :   11  | Train : 0.871  | Valid : 1.113  | Time : 8.66315s
# Training stopped:
# Epoch :   11  | Train Loss : 0.871  | Valid Loss: 1.113  | Test Loss: 1.127
# Time used = 10.228711416999886
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.001
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.277  | Valid : 1.285  | Time : 0.94892s
# Epoch :   11  | Train : 1.099  | Valid : 1.165  | Time : 8.65603s
# Training stopped:
# Epoch :   11  | Train Loss : 1.099  | Valid Loss: 1.165  | Test Loss: 1.172
# Time used = 10.174939041000016
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.001
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.275  | Valid : 1.284  | Time : 0.87068s
# Epoch :   11  | Train : 1.101  | Valid : 1.164  | Time : 8.61623s
# Training stopped:
# Epoch :   11  | Train Loss : 1.101  | Valid Loss: 1.164  | Test Loss: 1.171
# Time used = 10.049095542000032
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.001
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.262  | Valid : 1.271  | Time : 0.90190s
# Epoch :   11  | Train : 1.116  | Valid : 1.171  | Time : 8.69590s
# Training stopped:
# Epoch :   11  | Train Loss : 1.116  | Valid Loss: 1.171  | Test Loss: 1.182
# Time used = 10.153643749999901
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.0001
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.321  | Valid : 1.323  | Time : 0.91767s
# Epoch :   11  | Train : 1.274  | Valid : 1.283  | Time : 8.79250s
# Training stopped:
# Epoch :   11  | Train Loss : 1.274  | Valid Loss: 1.283  | Test Loss: 1.294
# Time used = 10.265324792000229
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.0001
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.322  | Valid : 1.322  | Time : 0.90396s
# Epoch :   11  | Train : 1.272  | Valid : 1.281  | Time : 8.68415s
# Training stopped:
# Epoch :   11  | Train Loss : 1.272  | Valid Loss: 1.281  | Test Loss: 1.293
# Time used = 10.130754000000252
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.0001
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.317  | Valid : 1.319  | Time : 0.87913s
# Epoch :   11  | Train : 1.256  | Valid : 1.267  | Time : 8.73727s
# Training stopped:
# Epoch :   11  | Train Loss : 1.256  | Valid Loss: 1.267  | Test Loss: 1.277
# Time used = 10.173272542000177
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.01
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.209  | Valid : 1.297  | Time : 0.95071s
# Epoch :   11  | Train : 0.631  | Valid : 1.121  | Time : 8.96390s
# Training stopped:
# Epoch :   11  | Train Loss : 0.631  | Valid Loss: 1.121  | Test Loss: 1.125
# Time used = 10.588762166999913
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.01
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.204  | Valid : 1.290  | Time : 0.92138s
# Epoch :   11  | Train : 0.751  | Valid : 1.117  | Time : 9.23957s
# Training stopped:
# Epoch :   11  | Train Loss : 0.751  | Valid Loss: 1.117  | Test Loss: 1.121
# Time used = 10.85029808299987
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.01
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.182  | Valid : 1.257  | Time : 1.02429s
# Epoch :   11  | Train : 0.862  | Valid : 1.128  | Time : 9.08034s
# Training stopped:
# Epoch :   11  | Train Loss : 0.862  | Valid Loss: 1.128  | Test Loss: 1.137
# Time used = 10.814794667000115
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.001
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.599  | Valid : 1.609  | Time : 0.94991s
# Epoch :   11  | Train : 1.193  | Valid : 1.284  | Time : 9.03766s
# Training stopped:
# Epoch :   11  | Train Loss : 1.193  | Valid Loss: 1.284  | Test Loss: 1.287
# Time used = 10.678794082999957
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.001
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.590  | Valid : 1.599  | Time : 0.93011s
# Epoch :   11  | Train : 1.189  | Valid : 1.277  | Time : 10.67275s
# Training stopped:
# Epoch :   11  | Train Loss : 1.189  | Valid Loss: 1.277  | Test Loss: 1.279
# Time used = 12.305071417000363
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.001
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.518  | Valid : 1.532  | Time : 0.97522s
# Epoch :   11  | Train : 1.171  | Valid : 1.249  | Time : 9.36767s
# Training stopped:
# Epoch :   11  | Train Loss : 1.171  | Valid Loss: 1.249  | Test Loss: 1.254
# Time used = 11.048486375000266
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.0001
# Epochs: 11
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.734  | Valid : 1.732  | Time : 1.00323s
# Epoch :   11  | Train : 1.589  | Valid : 1.600  | Time : 9.00969s
# Training stopped:
# Epoch :   11  | Train Loss : 1.589  | Valid Loss: 1.600  | Test Loss: 1.606
# Time used = 10.695486250000158
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.0001
# Epochs: 11
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.732  | Valid : 1.727  | Time : 0.95581s
# Epoch :   11  | Train : 1.578  | Valid : 1.588  | Time : 9.03007s
# Training stopped:
# Epoch :   11  | Train Loss : 1.578  | Valid Loss: 1.588  | Test Loss: 1.595
# Time used = 10.686413500000072
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.0001
# Epochs: 11
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.717  | Valid : 1.715  | Time : 0.91949s
# Epoch :   11  | Train : 1.504  | Valid : 1.519  | Time : 9.15290s
# Training stopped:
# Epoch :   11  | Train Loss : 1.504  | Valid Loss: 1.519  | Test Loss: 1.524
# Time used = 10.756814666000082
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.01
# Epochs: 101
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.064  | Valid : 1.106  | Time : 0.88192s
# Epoch :   11  | Train : 0.797  | Valid : 1.063  | Time : 8.37063s
# Training stopped:
# Epoch :   11  | Train Loss : 0.797  | Valid Loss: 1.063  | Test Loss: 1.076
# Time used = 9.629703250000148
# Saving Model
# ==============================
# ==============================
# features: 3
# learning rate: 0.01
# Epochs: 101
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.067  | Valid : 1.108  | Time : 0.90748s
# Epoch :   11  | Train : 0.807  | Valid : 1.064  | Time : 8.21587s
# Training stopped:
# Epoch :   12  | Train Loss : 0.789  | Valid Loss: 1.063  | Test Loss: 1.078
# Time used = 10.329522749999796
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.01
# Epochs: 101
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.067  | Valid : 1.112  | Time : 0.94367s
# Epoch :   11  | Train : 0.767  | Valid : 1.066  | Time : 8.28735s
# Training stopped:
# Epoch :   12  | Train Loss : 0.744  | Valid Loss: 1.065  | Test Loss: 1.077
# Time used = 10.521632791999764
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.01
# Epochs: 101
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.070  | Valid : 1.114  | Time : 0.84301s
# Epoch :   11  | Train : 0.798  | Valid : 1.067  | Time : 8.38803s
# Training stopped:
# Epoch :   13  | Train Loss : 0.763  | Valid Loss: 1.065  | Test Loss: 1.078
# Time used = 11.29478520900011
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.01
# Epochs: 101
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.097  | Valid : 1.138  | Time : 0.89014s
# Training stopped:
# Epoch :   10  | Train Loss : 0.896  | Valid Loss: 1.109  | Test Loss: 1.127
# Time used = 9.109244833000048
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.001
# Epochs: 101
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.163  | Valid : 1.171  | Time : 0.89709s
# Epoch :   11  | Train : 1.061  | Valid : 1.109  | Time : 8.31305s
# Epoch :   21  | Train : 1.013  | Valid : 1.093  | Time : 8.42942s
# Training stopped:
# Epoch :   23  | Train Loss : 1.005  | Valid Loss: 1.091  | Test Loss: 1.102
# Time used = 19.756233875000362
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.001
# Epochs: 101
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.163  | Valid : 1.172  | Time : 0.85016s
# Epoch :   11  | Train : 1.064  | Valid : 1.111  | Time : 8.28351s
# Epoch :   21  | Train : 1.018  | Valid : 1.095  | Time : 8.32054s
# Training stopped:
# Epoch :   23  | Train Loss : 1.010  | Valid Loss: 1.093  | Test Loss: 1.105
# Time used = 19.68493279200038
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.001
# Epochs: 101
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.167  | Valid : 1.175  | Time : 0.88501s
# Epoch :   11  | Train : 1.093  | Valid : 1.136  | Time : 8.36090s
# Training stopped:
# Epoch :   16  | Train Loss : 1.074  | Valid Loss: 1.130  | Test Loss: 1.146
# Time used = 13.881829832999756
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.0001
# Epochs: 101
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.186  | Valid : 1.190  | Time : 0.90979s
# Epoch :   11  | Train : 1.161  | Valid : 1.170  | Time : 8.37715s
# Epoch :   21  | Train : 1.142  | Valid : 1.155  | Time : 8.43771s
# Training stopped:
# Epoch :   29  | Train Loss : 1.130  | Valid Loss: 1.146  | Test Loss: 1.162
# Time used = 24.885398333000012
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.0001
# Epochs: 101
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.186  | Valid : 1.190  | Time : 0.91006s
# Epoch :   11  | Train : 1.161  | Valid : 1.170  | Time : 8.34223s
# Epoch :   21  | Train : 1.143  | Valid : 1.156  | Time : 8.29916s
# Training stopped:
# Epoch :   28  | Train Loss : 1.132  | Valid Loss: 1.148  | Test Loss: 1.164
# Time used = 23.87352645899955
# Saving Model
# ==============================
# ==============================
# features: 30
# learning rate: 0.0001
# Epochs: 101
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.187  | Valid : 1.191  | Time : 0.87885s
# Epoch :   11  | Train : 1.165  | Valid : 1.174  | Time : 8.34139s
# Training stopped:
# Epoch :   17  | Train Loss : 1.156  | Valid Loss: 1.168  | Test Loss: 1.184
# Time used = 14.75564737500008
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.01
# Epochs: 101
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.109  | Valid : 1.172  | Time : 0.95821s
# Epoch :   11  | Train : 0.688  | Valid : 1.086  | Time : 8.60704s
# Training stopped:
# Epoch :   14  | Train Loss : 0.587  | Valid Loss: 1.082  | Test Loss: 1.092
# Time used = 12.69851275000019
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.01
# Epochs: 101
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.109  | Valid : 1.170  | Time : 0.89336s
# Epoch :   11  | Train : 0.772  | Valid : 1.084  | Time : 8.71374s
# Training stopped:
# Epoch :   16  | Train Loss : 0.681  | Valid Loss: 1.078  | Test Loss: 1.088
# Time used = 14.48161116600022
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.01
# Epochs: 101
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.121  | Valid : 1.175  | Time : 1.03171s
# Epoch :   11  | Train : 0.872  | Valid : 1.113  | Time : 8.57087s
# Training stopped:
# Epoch :   11  | Train Loss : 0.872  | Valid Loss: 1.113  | Test Loss: 1.127
# Time used = 10.163245624999945
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.001
# Epochs: 101
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.278  | Valid : 1.286  | Time : 0.96361s
# Epoch :   11  | Train : 1.100  | Valid : 1.165  | Time : 8.55254s
# Epoch :   21  | Train : 1.027  | Valid : 1.134  | Time : 8.62730s
# Epoch :   31  | Train : 0.975  | Valid : 1.118  | Time : 8.78463s
# Training stopped:
# Epoch :   36  | Train Loss : 0.952  | Valid Loss: 1.113  | Test Loss: 1.121
# Time used = 31.81129483299992
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.001
# Epochs: 101
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.275  | Valid : 1.283  | Time : 0.99925s
# Epoch :   11  | Train : 1.101  | Valid : 1.164  | Time : 8.62938s
# Epoch :   21  | Train : 1.033  | Valid : 1.133  | Time : 8.74801s
# Epoch :   31  | Train : 0.986  | Valid : 1.118  | Time : 8.72714s
# Training stopped:
# Epoch :   36  | Train Loss : 0.967  | Valid Loss: 1.113  | Test Loss: 1.120
# Time used = 31.947104458000467
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.001
# Epochs: 101
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.260  | Valid : 1.271  | Time : 0.88912s
# Epoch :   11  | Train : 1.116  | Valid : 1.171  | Time : 8.63640s
# Epoch :   21  | Train : 1.065  | Valid : 1.149  | Time : 8.72265s
# Training stopped:
# Epoch :   29  | Train Loss : 1.036  | Valid Loss: 1.139  | Test Loss: 1.151
# Time used = 25.76735862500027
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.0001
# Epochs: 101
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.321  | Valid : 1.322  | Time : 0.91459s
# Epoch :   11  | Train : 1.273  | Valid : 1.283  | Time : 8.72159s
# Epoch :   21  | Train : 1.238  | Valid : 1.255  | Time : 8.75253s
# Epoch :   31  | Train : 1.212  | Valid : 1.235  | Time : 8.61425s
# Epoch :   41  | Train : 1.190  | Valid : 1.220  | Time : 8.59229s
# Epoch :   51  | Train : 1.172  | Valid : 1.208  | Time : 8.87412s
# Training stopped:
# Epoch :   57  | Train Loss : 1.162  | Valid Loss: 1.201  | Test Loss: 1.209
# Time used = 50.15111341700049
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.0001
# Epochs: 101
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.320  | Valid : 1.321  | Time : 0.88599s
# Epoch :   11  | Train : 1.271  | Valid : 1.280  | Time : 8.56347s
# Epoch :   21  | Train : 1.236  | Valid : 1.252  | Time : 8.78103s
# Epoch :   31  | Train : 1.209  | Valid : 1.232  | Time : 8.66641s
# Epoch :   41  | Train : 1.188  | Valid : 1.217  | Time : 8.93398s
# Epoch :   51  | Train : 1.170  | Valid : 1.205  | Time : 8.71046s
# Training stopped:
# Epoch :   56  | Train Loss : 1.162  | Valid Loss: 1.200  | Test Loss: 1.209
# Time used = 49.76456933300051
# Saving Model
# ==============================
# ==============================
# features: 150
# learning rate: 0.0001
# Epochs: 101
# weight decay: 2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.319  | Valid : 1.320  | Time : 0.97985s
# Epoch :   11  | Train : 1.257  | Valid : 1.268  | Time : 8.89590s
# Epoch :   21  | Train : 1.223  | Valid : 1.241  | Time : 8.68790s
# Epoch :   31  | Train : 1.200  | Valid : 1.224  | Time : 8.68625s
# Epoch :   41  | Train : 1.182  | Valid : 1.212  | Time : 8.58556s
# Training stopped:
# Epoch :   44  | Train Loss : 1.178  | Valid Loss: 1.209  | Test Loss: 1.219
# Time used = 38.94571816700045
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.0001
# Epochs: 101
# weight decay: 0.02
# stopping: 0.001
#
# Epoch :    1  | Train : 1.735  | Valid : 1.732  | Time : 0.92481s
# Epoch :   11  | Train : 1.589  | Valid : 1.600  | Time : 9.01349s
# Epoch :   21  | Train : 1.493  | Valid : 1.516  | Time : 8.98344s
# Epoch :   31  | Train : 1.425  | Valid : 1.458  | Time : 9.06219s
# Epoch :   41  | Train : 1.374  | Valid : 1.417  | Time : 9.04554s
# Epoch :   51  | Train : 1.334  | Valid : 1.385  | Time : 9.12436s
# Epoch :   61  | Train : 1.301  | Valid : 1.360  | Time : 9.07076s
# Epoch :   71  | Train : 1.273  | Valid : 1.339  | Time : 9.19351s
# Epoch :   81  | Train : 1.249  | Valid : 1.322  | Time : 10.08673s
# Epoch :   91  | Train : 1.228  | Valid : 1.307  | Time : 9.22021s
# Epoch :  101  | Train : 1.209  | Valid : 1.295  | Time : 9.07202s
# Training stopped:
# Epoch :  101  | Train Loss : 1.209  | Valid Loss: 1.295  | Test Loss: 1.297
# Time used = 93.5205822909993
# Saving Model
# ==============================
# ==============================
# features: 300
# learning rate: 0.0001
# Epochs: 101
# weight decay: 0.2
# stopping: 0.001
#
# Epoch :    1  | Train : 1.731  | Valid : 1.728  | Time : 0.94285s
# Epoch :   11  | Train : 1.578  | Valid : 1.589  | Time : 11.09126s
# Epoch :   21  | Train : 1.481  | Valid : 1.504  | Time : 9.12144s
# Epoch :   31  | Train : 1.413  | Valid : 1.447  | Time : 8.99294s
# Epoch :   41  | Train : 1.363  | Valid : 1.406  | Time : 9.01228s
# Epoch :   51  | Train : 1.324  | Valid : 1.375  | Time : 8.89042s
# Epoch :   61  | Train : 1.292  | Valid : 1.351  | Time : 9.04131s
# Epoch :   71  | Train : 1.266  | Valid : 1.331  | Time : 9.27646s
# Epoch :   81  | Train : 1.242  | Valid : 1.314  | Time : 10.50814s
# Epoch :   91  | Train : 1.222  | Valid : 1.299  | Time : 9.02330s
# Epoch :  101  | Train : 1.204  | Valid : 1.287  | Time : 9.08353s
# Training stopped:
# Epoch :  101  | Train Loss : 1.204  | Valid Loss: 1.287  | Test Loss: 1.290
# Time used = 95.74669145799999
# Saving Model
# ==============================
